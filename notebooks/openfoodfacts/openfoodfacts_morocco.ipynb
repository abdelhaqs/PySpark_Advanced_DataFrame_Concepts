# %%
from pyspark.sql import SparkSession
import requests
import os
from pyspark.sql import functions as F

# Initialize Spark session
spark = SparkSession.builder \
    .appName("OpenFoodFacts") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

# Define the URL and local path for the file
url = "https://huggingface.co/datasets/openfoodfacts/product-database/resolve/main/food.parquet"
local_file_path = "/home/jovyan/work/notebooks/openfoodfacts/food.parquet"

# Download the file if it doesn't exist locally
if not os.path.exists(local_file_path):
    print(f"Downloading file from {url}...")
    response = requests.get(url, stream=True)
    response.raise_for_status()  # Raise an exception for HTTP errors
    
    with open(local_file_path, "wb") as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)
    print(f"File downloaded successfully to {local_file_path}")
else:
    print(f"File already exists at {local_file_path}")

# Read the Parquet file into a Spark DataFrame
df = spark.read.parquet(local_file_path)

# Show the first few rows to verify the data was loaded correctly
df.show(5)

# Print the schema to see the structure of the data
df.printSchema()

# Filter products related to Morocco
filtered_df = df.filter(
    (F.array_contains(F.col("countries_tags"), "en:morocco")) |
    (F.array_contains(F.col("countries_tags"), "fr:morocco")) |
    (F.array_contains(F.col("countries_tags"), "ar:morocco")) |
    (F.array_contains(F.col("main_countries_tags"), "en:morocco")) |
    (F.array_contains(F.col("origins_tags"), "en:morocco")) |
    (F.lower(F.col("manufacturing_places")).like("%morocco%"))
)

# Show the count of filtered data
print(f"Filtered data count: {filtered_df.count()}")

# Define output path for CSV
output_csv_path = "/home/jovyan/work/notebooks/openfoodfacts/openfoodfacts_morocco.csv"

# Save the filtered DataFrame as a CSV file
filtered_df.coalesce(1).write.mode("overwrite").option("header", "true").csv(output_csv_path)
print(f"Filtered data saved to {output_csv_path}")

# Remove the large Parquet file to save space
os.remove(local_file_path)
print(f"Deleted large Parquet file: {local_file_path}")
# Out:
# Downloading file from https://huggingface.co/datasets/openfoodfacts/product-database/resolve/main/food.parquet...
# File downloaded successfully to /home/jovyan/work/notebooks/openfoodfacts/food.parquet
# +-----------+--------------+--------------+-----------+-------+--------------------+--------------------+-------------+---------------------+-----------+-------------+--------------------+--------+------------+--------------------+------------------+----------+---------------+------------------------+----------------------+--------------------------+--------------------+--------------------+--------------+--------------+-------------+-------+--------------+---------+--------------------+--------------------+------------+--------------------+--------------------+-------------------------+---------------------------+-------------+-------------------------+----------------------------+--------------------+--------------------+------------------------------------+--------------------------------------+----------------------------------+--------------------------------+--------------------+-------------------+--------------------+--------------------+----+------------------+--------------------+-----------------+------------+-----------------+---------------+--------------+----+-------------------+-------------------------+--------------------+---------+-------------+--------------------+---------------+-----------------+----------+--------------------+-----------+----------------+--------------------+--------------------+----------------+----------------+------------------+--------+------------+-------+------------+-----+-------------------+------------------------+---------------------+--------------+--------------+---------+--------------------+-------------+--------------+--------------------+--------------------+---------------------+----------------+--------------------+--------+---+-------+----------------+-----------------+--------------------+-----------+------+-----------+--------------+---------------------+----------------------+-------------+-----------------------------+---------------+
# |additives_n|additives_tags|allergens_tags|brands_tags| brands|          categories|     categories_tags|checkers_tags|ciqual_food_name_tags|cities_tags|         code|compared_to_category|complete|completeness|     correctors_tags|    countries_tags| created_t|        creator|data_quality_errors_tags|data_quality_info_tags|data_quality_warnings_tags|   data_sources_tags|       ecoscore_data|ecoscore_grade|ecoscore_score|ecoscore_tags|editors|emb_codes_tags|emb_codes|    entry_dates_tags|    food_groups_tags|generic_name|              images|      informers_tags|ingredients_analysis_tags|ingredients_from_palm_oil_n|ingredients_n|ingredients_original_tags|ingredients_percent_analysis|    ingredients_tags|    ingredients_text|ingredients_with_specified_percent_n|ingredients_with_unspecified_percent_n|ingredients_without_ciqual_codes_n|ingredients_without_ciqual_codes|         ingredients|known_ingredients_n|         labels_tags|              labels|lang|    languages_tags|last_edit_dates_tags|      last_editor|last_image_t| last_modified_by|last_modified_t|last_updated_t|link|main_countries_tags|manufacturing_places_tags|manufacturing_places|max_imgid|minerals_tags|           misc_tags|new_additives_n|no_nutrition_data|nova_group|    nova_groups_tags|nova_groups|nucleotides_tags|nutrient_levels_tags|          nutriments|nutriscore_grade|nutriscore_score|nutrition_data_per|obsolete|origins_tags|origins|owner_fields|owner|packagings_complete|packaging_recycling_tags|packaging_shapes_tags|packaging_tags|packaging_text|packaging|          packagings|photographers|popularity_key|     popularity_tags|        product_name|product_quantity_unit|product_quantity|purchase_places_tags|quantity|rev|scans_n|serving_quantity|     serving_size|         states_tags|stores_tags|stores|traces_tags|unique_scans_n|unknown_ingredients_n|unknown_nutrients_tags|vitamins_tags|with_non_nutritive_sweeteners|with_sweeteners|
# +-----------+--------------+--------------+-----------+-------+--------------------+--------------------+-------------+---------------------+-----------+-------------+--------------------+--------+------------+--------------------+------------------+----------+---------------+------------------------+----------------------+--------------------------+--------------------+--------------------+--------------+--------------+-------------+-------+--------------+---------+--------------------+--------------------+------------+--------------------+--------------------+-------------------------+---------------------------+-------------+-------------------------+----------------------------+--------------------+--------------------+------------------------------------+--------------------------------------+----------------------------------+--------------------------------+--------------------+-------------------+--------------------+--------------------+----+------------------+--------------------+-----------------+------------+-----------------+---------------+--------------+----+-------------------+-------------------------+--------------------+---------+-------------+--------------------+---------------+-----------------+----------+--------------------+-----------+----------------+--------------------+--------------------+----------------+----------------+------------------+--------+------------+-------+------------+-----+-------------------+------------------------+---------------------+--------------+--------------+---------+--------------------+-------------+--------------+--------------------+--------------------+---------------------+----------------+--------------------+--------+---+-------+----------------+-----------------+--------------------+-----------+------+-----------+--------------+---------------------+----------------------+-------------+-----------------------------+---------------+
# |       NULL|          NULL|     [en:nuts]|  [bovetti]|Bovetti|Petit-déjeuners,P...|[en:breakfasts, e...|           []| [chocolate-spread...|         []|0000101209159|en:cocoa-and-haze...|       0|      0.6875|[openfoodfacts-co...|       [en:france]|1519297017|        kiliweb|                      []|  [en:packaging-dat...|      [en:environmental...|    [app-yuka, apps]|{"status":"known"...|             d|            42|          [d]|   NULL|            []|         |[2018-02-22, 2018...|[en:sugary-snacks...|          []|[{ingredients_fr,...|[yuka.SGJvbVRKUXp...|                     NULL|                       NULL|         NULL|                     NULL|                        NULL|                NULL|                  []|                                NULL|                                  NULL|                              NULL|                            NULL|                NULL|               NULL|[en:no-gluten, en...|Sans gluten,Sans ...|  fr| [en:french, en:1]|[2024-11-14, 2024...|timotheeberthault|  1579374831|timotheeberthault|     1731601773|    1736316603|    |                 []|                       []|                    |        3|           []|[en:environmental...|           NULL|            false|      NULL|           [unknown]|       NULL|              []|[en:fat-in-high-q...|[{sugars, 32.0, 3...|               e|              25|              100g|   false|          []|       |        NULL| NULL|               true|    [en:recycle-in-so...|     [en:jar, en:lid]|            []|            []|         |[{en:glass, 1, 35...|         NULL|             0|                NULL|[{main, Véritable...|                    g|             350|                  []|   350 g| 18|   NULL|            NULL|             NULL|[en:to-be-complet...|         []|      |         []|          NULL|                 NULL|                    []|           []|                         NULL|           NULL|
# |          0|            []|            []|   [lagg-s]| Lagg's|Plant-based foods...|[en:plant-based-f...|           []|            [unknown]|       NULL|0000105000011|         en:tea-bags|       0|         0.5| [org-database-usda]|[en:united-states]|1489055330|usda-ndb-import|    [en:energy-value-...|  [en:no-packaging-...|      [en:energy-value-...|[database-usda-nd...|{"score":80,"stat...|             a|            80|          [a]|   NULL|          NULL|     NULL|[2017-03-09, 2017...|[en:beverages, en...|          []|                  []|[usda-ndb-import,...|     [en:palm-oil-free...|                          0|            1|     [en:camomile-flower]|                           1|[en:camomile-flow...|[{main, Chamomile...|                                   0|                                     1|                                 1|            [en:camomile-flower]|[{"percent_max":1...|                  3|                NULL|                NULL|  en|[en:english, en:1]|[2020-04-22, 2020...|org-database-usda|        NULL|org-database-usda|     1587573118|    1729985177|NULL|                 []|                     NULL|                NULL|     NULL|           []|[en:ecoscore-chan...|           NULL|             NULL|         1|[en:1-unprocessed...|          1|              []|                  []|[{sodium, 300.0, ...|         unknown|            NULL|              100g|   false|        NULL|   NULL|        NULL| NULL|               NULL|                      []|                   []|          NULL|            []|     NULL|                  []|         NULL|             1|[bottom-25-percen...|[{main, Lagg's, c...|                 NULL|            NULL|                NULL|    NULL|  2|      2|             1.0|  1 TEA BAG (1 g)|[en:to-be-complet...|       NULL|  NULL|         []|             1|                    0|                    []|           []|                         NULL|           NULL|
# |          0|            []|            []|   [lagg-s]| Lagg's|Plant-based foods...|[en:plant-based-f...|           []|            [unknown]|       NULL|0000105000042|         en:tea-bags|       0|         0.5| [org-database-usda]|[en:united-states]|1489055331|usda-ndb-import|                      []|  [en:no-packaging-...|      [en:serving-quant...|[database-usda-nd...|{"score":80,"stat...|             a|            80|          [a]|   NULL|          NULL|     NULL|[2017-03-09, 2017...|[en:beverages, en...|          []|                  []|[usda-ndb-import,...|     [en:palm-oil-free...|                          0|            1|          [en:peppermint]|                           1|[en:peppermint, e...|[{main, Peppermin...|                                   0|                                     1|                                 0|                              []|[{"percent_max":1...|                  3|                NULL|                NULL|  en|[en:english, en:1]|[2020-04-22, 2020...|org-database-usda|        NULL|org-database-usda|     1587573118|    1729985177|NULL|                 []|                     NULL|                NULL|     NULL|           []|[en:ecoscore-chan...|           NULL|             NULL|         1|[en:1-unprocessed...|          1|              []|                  []|[{carbohydrates, ...|         unknown|            NULL|              100g|   false|        NULL|   NULL|        NULL| NULL|               NULL|                      []|                   []|          NULL|            []|     NULL|                  []|         NULL|             0|                NULL|[{main, Lagg's, h...|                 NULL|            NULL|                NULL|    NULL|  2|   NULL|            45.0|  1.61 ONZ (45 g)|[en:to-be-complet...|       NULL|  NULL|         []|          NULL|                    0|                    []|           []|                         NULL|           NULL|
# |          0|            []|            []|   [lagg-s]| Lagg's|                NULL|                NULL|           []|            [unknown]|       NULL|0000105000059|                NULL|       0|         0.4|                  []|[en:united-states]|1489055331|usda-ndb-import|    [en:energy-value-...|  [en:no-packaging-...|      [en:ingredients-u...|[database-usda-nd...|{"agribalyse":{"w...|       unknown|          NULL|    [unknown]|   NULL|          NULL|     NULL|[2017-03-09, 2017...|                  []|          []|                  []|   [usda-ndb-import]|     [en:palm-oil-cont...|                          0|            1|      [en:linden-flowers]|                           1| [en:linden-flowers]|[{main, Linden fl...|                                   0|                                     1|                                 1|             [en:linden-flowers]|[{"percent_max":1...|                  0|                NULL|                NULL|  en|[en:english, en:1]|[2017-03-09, 2017...|  usda-ndb-import|        NULL|  usda-ndb-import|     1489055331|    1707490129|NULL|                 []|                     NULL|                NULL|     NULL|           []|[en:packagings-nu...|           NULL|             NULL|      NULL|           [unknown]|       NULL|              []|                  []|[{sodium, 0.0, 0....|         unknown|            NULL|              100g|   false|        NULL|   NULL|        NULL| NULL|               NULL|                      []|                   []|          NULL|            []|     NULL|                  []|         NULL|             0|                NULL|[{main, Linden Fl...|                 NULL|            NULL|                NULL|    NULL|  1|   NULL|             1.5|    1.5 g (1.5 g)|[en:to-be-complet...|       NULL|  NULL|         []|          NULL|                    1|                    []|           []|                         NULL|           NULL|
# |          0|            []|            []|   [lagg-s]| Lagg's|                NULL|                NULL|           []|            [unknown]|       NULL|0000105000073|                NULL|       0|         0.4|                  []|[en:united-states]|1489096571|usda-ndb-import|    [en:nutrition-val...|  [en:no-packaging-...|      [en:energy-value-...|[database-usda-nd...|{"status":"unknow...|       unknown|          NULL|    [unknown]|   NULL|          NULL|     NULL|[2017-03-09, 2017...|                  []|          []|                  []|   [usda-ndb-import]|     [en:palm-oil-free...|                          0|            1|      [en:roselle-flower]|                           1|[en:roselle-flowe...|[{main, Hibiscus ...|                                   0|                                     1|                                 1|             [en:roselle-flower]|[{"percent_max":1...|                  2|                NULL|                NULL|  en|[en:english, en:1]|[2017-03-09, 2017...|  usda-ndb-import|        NULL|  usda-ndb-import|     1489096571|    1707490129|NULL|                 []|                     NULL|                NULL|     NULL|           []|[en:packagings-nu...|           NULL|             NULL|      NULL|           [unknown]|       NULL|              []|                  []|[{energy-kcal, 26...|         unknown|            NULL|              100g|   false|        NULL|   NULL|        NULL| NULL|               NULL|                      []|                   []|          NULL|            []|     NULL|                  []|         NULL|             0|                NULL|[{main, Herbal Te...|                 NULL|            NULL|                NULL|    NULL|  1|   NULL|             1.5|1.5 g (1 TEA BAG)|[en:to-be-complet...|       NULL|  NULL|         []|          NULL|                    0|                    []|           []|                         NULL|           NULL|
# +-----------+--------------+--------------+-----------+-------+--------------------+--------------------+-------------+---------------------+-----------+-------------+--------------------+--------+------------+--------------------+------------------+----------+---------------+------------------------+----------------------+--------------------------+--------------------+--------------------+--------------+--------------+-------------+-------+--------------+---------+--------------------+--------------------+------------+--------------------+--------------------+-------------------------+---------------------------+-------------+-------------------------+----------------------------+--------------------+--------------------+------------------------------------+--------------------------------------+----------------------------------+--------------------------------+--------------------+-------------------+--------------------+--------------------+----+------------------+--------------------+-----------------+------------+-----------------+---------------+--------------+----+-------------------+-------------------------+--------------------+---------+-------------+--------------------+---------------+-----------------+----------+--------------------+-----------+----------------+--------------------+--------------------+----------------+----------------+------------------+--------+------------+-------+------------+-----+-------------------+------------------------+---------------------+--------------+--------------+---------+--------------------+-------------+--------------+--------------------+--------------------+---------------------+----------------+--------------------+--------+---+-------+----------------+-----------------+--------------------+-----------+------+-----------+--------------+---------------------+----------------------+-------------+-----------------------------+---------------+
# only showing top 5 rows
#
# root
#  |-- additives_n: integer (nullable = true)
#  |-- additives_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- allergens_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- brands_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- brands: string (nullable = true)
#  |-- categories: string (nullable = true)
#  |-- categories_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- checkers_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ciqual_food_name_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- cities_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- code: string (nullable = true)
#  |-- compared_to_category: string (nullable = true)
#  |-- complete: integer (nullable = true)
#  |-- completeness: float (nullable = true)
#  |-- correctors_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- countries_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- created_t: long (nullable = true)
#  |-- creator: string (nullable = true)
#  |-- data_quality_errors_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- data_quality_info_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- data_quality_warnings_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- data_sources_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ecoscore_data: string (nullable = true)
#  |-- ecoscore_grade: string (nullable = true)
#  |-- ecoscore_score: integer (nullable = true)
#  |-- ecoscore_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- editors: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- emb_codes_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- emb_codes: string (nullable = true)
#  |-- entry_dates_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- food_groups_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- generic_name: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- images: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- key: string (nullable = true)
#  |    |    |-- imgid: integer (nullable = true)
#  |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |-- 100: struct (nullable = true)
#  |    |    |    |    |-- h: integer (nullable = true)
#  |    |    |    |    |-- w: integer (nullable = true)
#  |    |    |    |-- 200: struct (nullable = true)
#  |    |    |    |    |-- h: integer (nullable = true)
#  |    |    |    |    |-- w: integer (nullable = true)
#  |    |    |    |-- 400: struct (nullable = true)
#  |    |    |    |    |-- h: integer (nullable = true)
#  |    |    |    |    |-- w: integer (nullable = true)
#  |    |    |    |-- full: struct (nullable = true)
#  |    |    |    |    |-- h: integer (nullable = true)
#  |    |    |    |    |-- w: integer (nullable = true)
#  |    |    |-- uploaded_t: long (nullable = true)
#  |    |    |-- uploader: string (nullable = true)
#  |-- informers_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ingredients_analysis_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ingredients_from_palm_oil_n: integer (nullable = true)
#  |-- ingredients_n: integer (nullable = true)
#  |-- ingredients_original_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ingredients_percent_analysis: integer (nullable = true)
#  |-- ingredients_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ingredients_text: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- ingredients_with_specified_percent_n: integer (nullable = true)
#  |-- ingredients_with_unspecified_percent_n: integer (nullable = true)
#  |-- ingredients_without_ciqual_codes_n: integer (nullable = true)
#  |-- ingredients_without_ciqual_codes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- ingredients: string (nullable = true)
#  |-- known_ingredients_n: integer (nullable = true)
#  |-- labels_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- labels: string (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- languages_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- last_edit_dates_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- last_editor: string (nullable = true)
#  |-- last_image_t: long (nullable = true)
#  |-- last_modified_by: string (nullable = true)
#  |-- last_modified_t: long (nullable = true)
#  |-- last_updated_t: long (nullable = true)
#  |-- link: string (nullable = true)
#  |-- main_countries_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- manufacturing_places_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- manufacturing_places: string (nullable = true)
#  |-- max_imgid: integer (nullable = true)
#  |-- minerals_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- misc_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- new_additives_n: integer (nullable = true)
#  |-- no_nutrition_data: boolean (nullable = true)
#  |-- nova_group: integer (nullable = true)
#  |-- nova_groups_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- nova_groups: string (nullable = true)
#  |-- nucleotides_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- nutrient_levels_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- nutriments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- value: float (nullable = true)
#  |    |    |-- 100g: float (nullable = true)
#  |    |    |-- serving: float (nullable = true)
#  |    |    |-- unit: string (nullable = true)
#  |    |    |-- prepared_value: float (nullable = true)
#  |    |    |-- prepared_100g: float (nullable = true)
#  |    |    |-- prepared_serving: float (nullable = true)
#  |    |    |-- prepared_unit: string (nullable = true)
#  |-- nutriscore_grade: string (nullable = true)
#  |-- nutriscore_score: integer (nullable = true)
#  |-- nutrition_data_per: string (nullable = true)
#  |-- obsolete: boolean (nullable = true)
#  |-- origins_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- origins: string (nullable = true)
#  |-- owner_fields: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- field_name: string (nullable = true)
#  |    |    |-- timestamp: long (nullable = true)
#  |-- owner: string (nullable = true)
#  |-- packagings_complete: boolean (nullable = true)
#  |-- packaging_recycling_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- packaging_shapes_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- packaging_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- packaging_text: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- packaging: string (nullable = true)
#  |-- packagings: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- material: string (nullable = true)
#  |    |    |-- number_of_units: long (nullable = true)
#  |    |    |-- quantity_per_unit: string (nullable = true)
#  |    |    |-- quantity_per_unit_unit: string (nullable = true)
#  |    |    |-- quantity_per_unit_value: string (nullable = true)
#  |    |    |-- recycling: string (nullable = true)
#  |    |    |-- shape: string (nullable = true)
#  |    |    |-- weight_measured: float (nullable = true)
#  |-- photographers: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- popularity_key: long (nullable = true)
#  |-- popularity_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- product_name: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- product_quantity_unit: string (nullable = true)
#  |-- product_quantity: string (nullable = true)
#  |-- purchase_places_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- quantity: string (nullable = true)
#  |-- rev: integer (nullable = true)
#  |-- scans_n: integer (nullable = true)
#  |-- serving_quantity: string (nullable = true)
#  |-- serving_size: string (nullable = true)
#  |-- states_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- stores_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- stores: string (nullable = true)
#  |-- traces_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- unique_scans_n: integer (nullable = true)
#  |-- unknown_ingredients_n: integer (nullable = true)
#  |-- unknown_nutrients_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- vitamins_tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- with_non_nutritive_sweeteners: integer (nullable = true)
#  |-- with_sweeteners: integer (nullable = true)
